# %% [markdown]
# ## Overview of Assignment 4
#
# This assignment focuses on exploring and implementing advanced concepts and techniques in information retrieval. The primary objectives are to build Retrieval Augumentation Generation, and learn about Language Models

# %% [markdown]
# ## Enter your details below

# %% [markdown]
# ## Name

# %% [markdown]
# Antonia Mugisa

# %% [markdown]
# ## Banner ID

# %% [markdown]
# B00856440

# %% [markdown]
# ## GitHub Link of your Assingment 4

# %% [markdown]
# https://github.com/CSCI4141/assignment-4-antoniamugisa

# %% [markdown]
# ## Q1 : Setting up the libraries and the environment

# %%
! pip3 install datasets
! pip3 install transformers
! pip3 install tqdm 
! pip3 install urllib3==1.26.16
! pip3 install --upgrade jupyter ipywidgets 
! pip3 install faiss-cpu
! pip3 install --upgrade langchain 
! pip3 install langchain_community
! pip3 install langchain_huggingface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (2.20.0)
# Requirement already satisfied: multiprocess in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: requests>=2.32.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: xxhash in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (0.24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: pandas in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: packaging in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (24.1)
# Requirement already satisfied: filelock in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (3.15.4)
# Requirement already satisfied: aiohttp in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (2024.5.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (0.6)
# Requirement already satisfied: numpy>=1.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests>=2.32.2->datasets) (1.26.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (4.43.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: filelock in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: requests in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (24.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers) (0.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (1.26.16)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (4.66.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: urllib3==1.26.16 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (1.26.16)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (8.1.3)
# Requirement already satisfied: ipykernel in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: nbconvert in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: notebook in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter) (7.2.1)
# Requirement already satisfied: jupyter-console in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: qtconsole in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (4.0.11)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: comm>=0.1.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: jedi>=0.16 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: typing-extensions in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: decorator in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: stack-data in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: psutil in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: appnope in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: nest-asyncio in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: packaging in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: pyzmq>=24 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (1.8.2)
# Requirement already satisfied: tornado>=6.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (8.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel->jupyter) (3.19.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter) (1.15.0)
# Requirement already satisfied: bleach!=5.0.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: markupsafe>=2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: tinycss2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: jinja2>=3.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbformat>=5.7 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: beautifulsoup4 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: webencodings in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.7->nbconvert->jupyter) (4.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (0.19.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (4.2.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: overrides>=5.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: idna>=2.8 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: uri-template in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (24.6.0)
# Requirement already satisfied: fqdn in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (3.0.0)
# Requirement already satisfied: tomli>=1.2.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (58.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: httpcore==1.* in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: certifi in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.7.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: requests>=2.31 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: json5>=0.9.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: babel>=2.10 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: cffi>=1.0.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter) (2.9.0.20240316)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faiss-cpu in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (1.8.0.post1)
# Requirement already satisfied: packaging in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: numpy<2.0,>=1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from faiss-cpu) (1.26.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (0.2.12)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: numpy<2,>=1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (2.0.31)
# Requirement already satisfied: requests<3,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (0.1.96)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain) (0.2.28)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (24.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.6)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain_community in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (0.2.11)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (0.2.28)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (0.1.96)
# Requirement already satisfied: langchain<0.3.0,>=0.2.12 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (0.2.12)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (2.0.31)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: numpy<2,>=1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: requests<3,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain<0.3.0,>=0.2.12->langchain_community) (2.8.2)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain<0.3.0,>=0.2.12->langchain_community) (0.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (4.12.2)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain_community) (24.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain_community) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.6)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.12->langchain_community) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.12->langchain_community) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain_community) (1.26.16)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain_huggingface in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (0.0.3)
# Requirement already satisfied: transformers>=4.39.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_huggingface) (4.43.3)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_huggingface) (0.2.28)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_huggingface) (3.0.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_huggingface) (0.24.2)
# Requirement already satisfied: tokenizers>=0.19.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain_huggingface) (0.19.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (6.0.1)
# Requirement already satisfied: filelock in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2024.5.0)
# Requirement already satisfied: requests in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.12.2)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (4.66.4)
# Requirement already satisfied: packaging>=20.9 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.23.0->langchain_huggingface) (24.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.1.96)
# Requirement already satisfied: pydantic<3,>=1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain_huggingface) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain_huggingface) (3.10.6)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain_huggingface) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.52->langchain_huggingface) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.23.0->langchain_huggingface) (3.7)
# Requirement already satisfied: scipy in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (2.4.0)
# Requirement already satisfied: numpy in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.26.4)
# Requirement already satisfied: Pillow in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (10.4.0)
# Requirement already satisfied: scikit-learn in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=2.6.0->langchain_huggingface) (1.5.1)
# Requirement already satisfied: networkx in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (3.1.4)
# Requirement already satisfied: sympy in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers>=4.39.0->langchain_huggingface) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from transformers>=4.39.0->langchain_huggingface) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (2.1.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/antoniamugisa/Library/Python/3.9/lib/python/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface) (1.3.0)

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, BertModel, pipeline
import numpy as np
import torch
from torch.utils.data import DataLoader
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores.base import VectorStore
from langchain_huggingface import HuggingFacePipeline
from langchain.chains import retrieval_qa
from langchain_community.document_loaders import HuggingFaceDatasetLoader
from langchain.docstore import InMemoryDocstore
from langchain_core.documents import Document

# %% [markdown]
# ## Q2:  Data Preprocessing and Model Selection

# %%
# 1. 
# Load dataset 

# Create a loader instance
dataset = load_dataset("danioshi/incubus_taylor_swift_lyrics", split="train")

# %%
# 2. 
# Tokenize data

# Load a pre-trained tokenizer (you can choose a different one if needed)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Tokenize the dataset
def tokenize_function(example):
    return tokenizer(example["lyrics"], padding="max_length", truncation=True)

# Apply the tokenizer to the dataset
tokenizer_ds = dataset.map(tokenize_function, batched=True)

# %%
# 3. 

#Split into chunks for indexing 

def chunk_examples(example, chunk_size=128):
    input_ids = example["input_ids"]
    chunks = [input_ids[i:i + chunk_size] for i in range(0, len(input_ids), chunk_size)]
    return {"chunks": chunks}

# Apply the chunking function
chunked_ds = tokenizer_ds.map(chunk_examples, batched=False)

# %%
# 4. 

# Create a vector store

# Load the model and tokenizer
# Load the model and tokenizer
model = BertModel.from_pretrained("bert-base-uncased")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Function to generate embeddings from token IDs
def get_embeddings(input_ids_batch):
    input_ids_batch = [torch.tensor(ids).to(device) for ids in input_ids_batch]  # Convert each chunk to tensor
    with torch.no_grad():
        outputs = [model(input_ids=ids.unsqueeze(0)).last_hidden_state[:, 0].cpu().numpy() for ids in input_ids_batch]
        return np.vstack(outputs)  # Stack the embeddings to form a single numpy array

# Apply the embedding function to your dataset
def add_embeddings(example):
    # Flatten the list of chunks
    flattened_chunks = [item for sublist in example['chunks'] for item in sublist]
    # Generate embeddings
    example['embeddings'] = get_embeddings(flattened_chunks)
    return example

# Apply the function to your chunked dataset
chunked_ds_with_embeddings = chunked_ds.map(add_embeddings, batched=False)

# Prepare DataLoader for batch processing
def collate_fn(batch):
    # Flatten the list of chunks and create a single batch
    input_ids_batch = [example['chunks'] for example in batch]
    return input_ids_batch

dataloader = DataLoader(chunked_ds_with_embeddings, batch_size=32, collate_fn=collate_fn)

# Generate embeddings for the entire dataset
embeddings_list = []
documents = []

for batch in dataloader:
    batch_embeddings = get_embeddings(batch)
    embeddings_list.extend(batch_embeddings)
    # Assuming you need to collect documents from the same dataset
    documents.extend(
        Document(page_content=example['lyrics']) 
        for example in chunked_ds_with_embeddings if example['chunks'] in batch)

# Convert to numpy array
embeddings_array = np.array(embeddings_list, dtype=np.float32)

# Define the dimension of embeddings (should match the size of individual embeddings)
dimension = embeddings_array.shape[1]

# Initialize FAISS index
index = faiss.IndexFlatL2(dimension)

# Add embeddings to FAISS index
index.add(embeddings_array)

print("FAISS index created and embeddings added.")
# Out:
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# Map:   0%|          | 0/267 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 27
#      24     return example
#      26 # Apply the function to your chunked dataset
# ---> 27 chunked_ds_with_embeddings = chunked_ds.map(add_embeddings, batched=False)
#      29 # Prepare DataLoader for batch processing
#      30 def collate_fn(batch):
#      31     # Flatten the list of chunks and create a single batch
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/arrow_dataset.py:3161, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3155 if transformed_dataset is None:
#    3156     with hf_tqdm(
#    3157         unit=" examples",
#    3158         total=pbar_total,
#    3159         desc=desc or "Map",
#    3160     ) as pbar:
# -> 3161         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3162             if done:
#    3163                 shards_done += 1
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/arrow_dataset.py:3522, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3520 _time = time.time()
#    3521 for i, example in shard_iterable:
# -> 3522     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#    3523     if update_data:
#    3524         if i == 0:
#
# File ~/Library/Python/3.9/lib/python/site-packages/datasets/arrow_dataset.py:3421, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3419 if with_rank:
#    3420     additional_args += (rank,)
# -> 3421 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3422 if isinstance(processed_inputs, LazyDict):
#    3423     processed_inputs = {
#    3424         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3425     }
#
# Cell In[13], line 23, in add_embeddings(example)
#      21 flattened_chunks = [item for sublist in example['chunks'] for item in sublist]
#      22 # Generate embeddings
# ---> 23 example['embeddings'] = get_embeddings(flattened_chunks)
#      24 return example
#
# Cell In[13], line 15, in get_embeddings(input_ids_batch)
#      13 input_ids_batch = [torch.tensor(ids).to(device) for ids in input_ids_batch]  # Convert each chunk to tensor
#      14 with torch.no_grad():
# ---> 15     outputs = [model(input_ids=ids.unsqueeze(0)).last_hidden_state[:, 0].cpu().numpy() for ids in input_ids_batch]
#      16     return np.vstack(outputs)
#
# Cell In[13], line 15, in <listcomp>(.0)
#      13 input_ids_batch = [torch.tensor(ids).to(device) for ids in input_ids_batch]  # Convert each chunk to tensor
#      14 with torch.no_grad():
# ---> 15     outputs = [model(input_ids=ids.unsqueeze(0)).last_hidden_state[:, 0].cpu().numpy() for ids in input_ids_batch]
#      16     return np.vstack(outputs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/bert/modeling_bert.py:1056, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1054     raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#    1055 elif input_ids is not None:
# -> 1056     self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#    1057     input_shape = input_ids.size()
#    1058 elif inputs_embeds is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/modeling_utils.py:4640, in PreTrainedModel.warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    4637     return
#    4639 # Check only the first and last input IDs to reduce overhead.
# -> 4640 if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    4641     warn_string = (
#    4642         "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#    4643         "https://huggingface.co/docs/transformers/troubleshooting"
#    4644         "#incorrect-output-when-padding-tokens-arent-masked."
#    4645     )
#    4647     # If the pad token is equal to either BOS, EOS, or SEP, we do not know whether the user should use an
#    4648     # attention_mask or not. In this case, we should still show a warning because this is a rare case.
#
# IndexError: too many indices for tensor of dimension 1

# %% [markdown]
# ## Q3: Implementing RAG using LangChain for different queries

# %% [markdown]
# 1.
#
# Retrieval-Augmented Generation (RAG) is an approach that enhances language model outputs by integrating external knowledge. It combines retrieval and generation to produce more informed responses. Here's a brief overview:
#
# Components:
#
# 1. Query Encoder: Converts the input query into a vector to capture its meaning. Typically uses models like BERT.
#
# 2. Retriever: Searches a knowledge base for relevant documents using the query vector. Employs techniques like FAISS or BM25.
#
# 3. Document Encoder: Converts retrieved documents into vectors compatible with the generator.
#
# 4. Generator: Combines the query and document vectors to generate a context-rich response. Uses models like GPT.
#
# 5. Knowledge Base: The source of external information, such as Wikipedia.
#
# Workflow:
#
# 1. Input Handling: Receive and encode the query.
# 2. Retrieval: Find relevant documents.
# 3. Encoding: Encode documents into vectors.
# 4. Generation: Produce a response using the combined vectors.
# 5. Output: Deliver an informed, context-aware response.
#
# Advantages:
#
# - Knowledge Integration: Generates more informed outputs.
# - Flexibility: Adaptable to various domains.
# - Scalability: Efficiently handles large datasets.
#
# Use Cases:
#
# - Question Answering: Provides accurate, contextually enhanced answers.
# - Customer Support: Improves automated response quality.
# - Content Generation: Creates comprehensive, well-informed content.
#
# RAG effectively combines pre-trained models with external knowledge sources for more accurate text generation.

# %% [markdown]
# 2.
#
# I have chosen to use T5, a text-to-text transformer. It is highly adaptable for retrieveal and generation. It is pretrained on the C4 dataset, which is provides it with broad general knowledge. T5 is also available in various sizes and allows customization to increase performance on RAG tasks.

# %%
# 3

# Create an InMemoryDocstore
docstore = InMemoryDocstore({str(i): doc for i, doc in enumerate(documents)})

# Create an index_to_docstore_id mapping
index_to_docstore_id = {i: str(i) for i in range(len(documents))}

# Initialize FAISS vector store with required arguments
hf_embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2",
    encode_kwargs={'normalize_embeddings': False}
)

vs = FAISS(
    index=index,
    docstore=docstore,
    index_to_docstore_id=index_to_docstore_id,
    embedding_function=hf_embeddings
)

# Create retriever from vector store
retriever = vs.as_retriever()

# Initialize the Hugging Face pipeline for text generation
hf_pipeline = pipeline(
    "text2text-generation", 
    model="t5-base", 
    device=0,  # Specify GPU if available
    max_length=150
)

# Wrap the Hugging Face pipeline using HuggingFacePipeline from LangChain
llm = HuggingFacePipeline(pipeline=hf_pipeline)

# Construct the RAG-like pipeline using RetrievalQA
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="refine",
    retriever=retriever,
    return_source_documents=False
)

# Step 6: Perform a query
query = "What are the common themes in Taylor Swift's lyrics?"
result = qa.invoke({"query": query})

# Step 7: Display the result
print("Generated Response:", result["result"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[167], line 46
#      44 # Step 6: Perform a query
#      45 query = "What are the common themes in Taylor Swift's lyrics?"
# ---> 46 result = qa.invoke({"query": query})
#      48 # Step 7: Display the result
#      49 print("Generated Response:", result["result"])
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/retrieval_qa/base.py:146, in BaseRetrievalQA._call(self, inputs, run_manager)
#     144 else:
#     145     docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 146 answer = self.combine_documents_chain.run(
#     147     input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     148 )
#     150 if self.return_source_documents:
#     151     return {self.output_key: answer, "source_documents": docs}
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/_api/deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:605, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     600     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     601         _output_key
#     602     ]
#     604 if kwargs and not args:
# --> 605     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     606         _output_key
#     607     ]
#     609 if not kwargs and not args:
#     610     raise ValueError(
#     611         "`run` supported with either positional arguments or keyword arguments,"
#     612         " but none were provided."
#     613     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/_api/deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
#     353 Args:
#    (...)
#     374         `Chain.output_keys`.
#     375 """
#     376 config = {
#     377     "callbacks": callbacks,
#     378     "tags": tags,
#     379     "metadata": metadata,
#     380     "run_name": run_name,
#     381 }
# --> 383 return self.invoke(
#     384     inputs,
#     385     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     386     return_only_outputs=return_only_outputs,
#     387     include_run_info=include_run_info,
#     388 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/combine_documents/base.py:138, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     136 # Other keys are assumed to be needed for LLM prediction
#     137 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 138 output, extra_return_dict = self.combine_docs(
#     139     docs, callbacks=_run_manager.get_child(), **other_keys
#     140 )
#     141 extra_return_dict[self.output_key] = output
#     142 return extra_return_dict
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/combine_documents/refine.py:154, in RefineDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     141 """Combine by mapping first chain over all, then stuffing into final chain.
#     142
#     143 Args:
#    (...)
#     151     element returned is a dictionary of other keys to return.
#     152 """
#     153 inputs = self._construct_initial_inputs(docs, **kwargs)
# --> 154 res = self.initial_llm_chain.predict(callbacks=callbacks, **inputs)
#     155 refine_steps = [res]
#     156 for doc in docs[1:]:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/_api/deprecation.py:168, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     166     warned = True
#     167     emit_warning()
# --> 168 return wrapped(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
#     353 Args:
#    (...)
#     374         `Chain.output_keys`.
#     375 """
#     376 config = {
#     377     "callbacks": callbacks,
#     378     "tags": tags,
#     379     "metadata": metadata,
#     380     "run_name": run_name,
#     381 }
# --> 383 return self.invoke(
#     384     inputs,
#     385     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     386     return_only_outputs=return_only_outputs,
#     387     include_run_info=include_run_info,
#     388 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/llm.py:128, in LLMChain._call(self, inputs, run_manager)
#     123 def _call(
#     124     self,
#     125     inputs: Dict[str, Any],
#     126     run_manager: Optional[CallbackManagerForChainRun] = None,
#     127 ) -> Dict[str, str]:
# --> 128     response = self.generate([inputs], run_manager=run_manager)
#     129     return self.create_outputs(response)[0]
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain/chains/llm.py:140, in LLMChain.generate(self, input_list, run_manager)
#     138 callbacks = run_manager.get_child() if run_manager else None
#     139 if isinstance(self.llm, BaseLanguageModel):
# --> 140     return self.llm.generate_prompt(
#     141         prompts,
#     142         stop,
#     143         callbacks=callbacks,
#     144         **self.llm_kwargs,
#     145     )
#     146 else:
#     147     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     148         cast(List, prompts), {"callbacks": callbacks}
#     149     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/language_models/llms.py:703, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     695 def generate_prompt(
#     696     self,
#     697     prompts: List[PromptValue],
#    (...)
#     700     **kwargs: Any,
#     701 ) -> LLMResult:
#     702     prompt_strings = [p.to_string() for p in prompts]
# --> 703     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/language_models/llms.py:882, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     867 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     868     run_managers = [
#     869         callback_manager.on_llm_start(
#     870             dumpd(self),
#    (...)
#     880         )
#     881     ]
# --> 882     output = self._generate_helper(
#     883         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     884     )
#     885     return output
#     886 if len(missing_prompts) > 0:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/language_models/llms.py:740, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     738     for run_manager in run_managers:
#     739         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 740     raise e
#     741 flattened_outputs = output.flatten()
#     742 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/language_models/llms.py:727, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     717 def _generate_helper(
#     718     self,
#     719     prompts: List[str],
#    (...)
#     723     **kwargs: Any,
#     724 ) -> LLMResult:
#     725     try:
#     726         output = (
# --> 727             self._generate(
#     728                 prompts,
#     729                 stop=stop,
#     730                 # TODO: support multiple run managers
#     731                 run_manager=run_managers[0] if run_managers else None,
#     732                 **kwargs,
#     733             )
#     734             if new_arg_supported
#     735             else self._generate(prompts, stop=stop)
#     736         )
#     737     except BaseException as e:
#     738         for run_manager in run_managers:
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_huggingface/llms/huggingface_pipeline.py:269, in HuggingFacePipeline._generate(self, prompts, stop, run_manager, **kwargs)
#     266 batch_prompts = prompts[i : i + self.batch_size]
#     268 # Process batch of prompts
# --> 269 responses = self.pipeline(
#     270     batch_prompts,
#     271     **pipeline_kwargs,
#     272 )
#     274 # Process each response in the batch
#     275 for j, response in enumerate(responses):
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pipelines/text2text_generation.py:167, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     138 def __call__(self, *args, **kwargs):
#     139     r"""
#     140     Generate the output text(s) using text(s) given as inputs.
#     141
#    (...)
#     164           ids of the generated text.
#     165     """
# --> 167     result = super().__call__(*args, **kwargs)
#     168     if (
#     169         isinstance(args[0], list)
#     170         and all(isinstance(el, str) for el in args[0])
#     171         and all(len(res) == 1 for res in result)
#     172     ):
#     173         return [res[0] for res in result]
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pipelines/base.py:1235, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1231 if can_use_iterator:
#    1232     final_iterator = self.get_iterator(
#    1233         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1234     )
# -> 1235     outputs = list(final_iterator)
#    1236     return outputs
#    1237 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pipelines/pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pipelines/base.py:1161, in Pipeline.forward(self, model_inputs, **forward_params)
#    1159     with inference_context():
#    1160         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1161         model_outputs = self._forward(model_inputs, **forward_params)
#    1162         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1163 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/pipelines/text2text_generation.py:191, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     184     in_b, input_length = tf.shape(model_inputs["input_ids"]).numpy()
#     186 self.check_inputs(
#     187     input_length,
#     188     generate_kwargs.get("min_length", self.model.config.min_length),
#     189     generate_kwargs.get("max_length", self.model.config.max_length),
#     190 )
# --> 191 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     192 out_b = output_ids.shape[0]
#     193 if self.framework == "pt":
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/generation/utils.py:1989, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1981     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1982         input_ids=input_ids,
#    1983         expand_size=generation_config.num_return_sequences,
#    1984         is_encoder_decoder=self.config.is_encoder_decoder,
#    1985         **model_kwargs,
#    1986     )
#    1988     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1989     result = self._sample(
#    1990         input_ids,
#    1991         logits_processor=prepared_logits_processor,
#    1992         logits_warper=prepared_logits_warper,
#    1993         stopping_criteria=prepared_stopping_criteria,
#    1994         generation_config=generation_config,
#    1995         synced_gpus=synced_gpus,
#    1996         streamer=streamer,
#    1997         **model_kwargs,
#    1998     )
#    2000 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2001     # 11. prepare logits warper
#    2002     prepared_logits_warper = (
#    2003         self._get_logits_warper(generation_config, device=input_ids.device)
#    2004         if generation_config.do_sample
#    2005         else None
#    2006     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/generation/utils.py:2932, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2929 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    2931 # forward pass to get next token
# -> 2932 outputs = self(**model_inputs, return_dict=True)
#    2934 if synced_gpus and this_peer_finished:
#    2935     continue  # don't waste resources running the code we don't need
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/t5/modeling_t5.py:1739, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1736         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1738 # Decode
# -> 1739 decoder_outputs = self.decoder(
#    1740     input_ids=decoder_input_ids,
#    1741     attention_mask=decoder_attention_mask,
#    1742     inputs_embeds=decoder_inputs_embeds,
#    1743     past_key_values=past_key_values,
#    1744     encoder_hidden_states=hidden_states,
#    1745     encoder_attention_mask=attention_mask,
#    1746     head_mask=decoder_head_mask,
#    1747     cross_attn_head_mask=cross_attn_head_mask,
#    1748     use_cache=use_cache,
#    1749     output_attentions=output_attentions,
#    1750     output_hidden_states=output_hidden_states,
#    1751     return_dict=return_dict,
#    1752 )
#    1754 sequence_output = decoder_outputs[0]
#    1756 # Set device for model parallelism
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/t5/modeling_t5.py:1106, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1091     layer_outputs = self._gradient_checkpointing_func(
#    1092         layer_module.forward,
#    1093         hidden_states,
#    (...)
#    1103         output_attentions,
#    1104     )
#    1105 else:
# -> 1106     layer_outputs = layer_module(
#    1107         hidden_states,
#    1108         attention_mask=extended_attention_mask,
#    1109         position_bias=position_bias,
#    1110         encoder_hidden_states=encoder_hidden_states,
#    1111         encoder_attention_mask=encoder_extended_attention_mask,
#    1112         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1113         layer_head_mask=layer_head_mask,
#    1114         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1115         past_key_value=past_key_value,
#    1116         use_cache=use_cache,
#    1117         output_attentions=output_attentions,
#    1118     )
#    1120 # layer_outputs is a tuple with:
#    1121 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1122 if use_cache is False:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/t5/modeling_t5.py:686, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     683 else:
#     684     self_attn_past_key_value, cross_attn_past_key_value = None, None
# --> 686 self_attention_outputs = self.layer[0](
#     687     hidden_states,
#     688     attention_mask=attention_mask,
#     689     position_bias=position_bias,
#     690     layer_head_mask=layer_head_mask,
#     691     past_key_value=self_attn_past_key_value,
#     692     use_cache=use_cache,
#     693     output_attentions=output_attentions,
#     694 )
#     695 hidden_states, present_key_value_state = self_attention_outputs[:2]
#     696 attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/t5/modeling_t5.py:592, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     582 def forward(
#     583     self,
#     584     hidden_states,
#    (...)
#     590     output_attentions=False,
#     591 ):
# --> 592     normed_hidden_states = self.layer_norm(hidden_states)
#     593     attention_output = self.SelfAttention(
#     594         normed_hidden_states,
#     595         mask=attention_mask,
#    (...)
#     600         output_attentions=output_attentions,
#     601     )
#     602     hidden_states = hidden_states + self.dropout(attention_output[0])
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/models/t5/modeling_t5.py:246, in T5LayerNorm.forward(self, hidden_states)
#     239 def forward(self, hidden_states):
#     240     # T5 uses a layer_norm which only scales and doesn't shift, which is also known as Root Mean
#     241     # Square Layer Normalization https://arxiv.org/abs/1910.07467 thus varience is calculated
#     242     # w/o mean and there is no bias. Additionally we want to make sure that the accumulation for
#     243     # half-precision inputs is done in fp32
#     245     variance = hidden_states.to(torch.float32).pow(2).mean(-1, keepdim=True)
# --> 246     hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     248     # convert into half-precision if necessary
#     249     if self.weight.dtype in [torch.float16, torch.bfloat16]:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Q4 : Modify and evaluate the different components of RAG

# %%
# 1.

# %% [markdown]
# 2.

# %%
# 3.

# %% [markdown]
# 4.

# %% [markdown]
# ## Q5: Selecting and implementing a pretrained model for a new task
